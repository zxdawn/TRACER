# %%
import tensorflow as tf
import numpy as np
import torch
import torch.nn as nn
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, LeakyReLU, Embedding, LSTM
from keras.callbacks import LearningRateScheduler

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import math
import numpy as np
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from scipy.stats import pearsonr 
from sklearn.metrics import r2_score


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#ShipDensity, UV, Vx, Vy, CF
#NO2

df = pd.read_csv("/content/drive/MyDrive/data.csv")
df
# Out:
#      Unnamed: 0  ShipDensity_GoM  ...     Temp_LA         UV_LA
# 0             0             2714  ...  288.734746  104686.78520
# 1             1               21  ...  289.782862  104370.73440
# 2             2             3290  ...  289.442891   98398.08594
# 3             3             1280  ...  290.500682   95001.85677
# 4             4             1689  ...  290.280014  105785.10290
# ..          ...              ...  ...         ...           ...
# 205         205             3651  ...  296.987956  278598.07550
# 206         206             3103  ...  297.034933  250787.73960
# 207         207             2247  ...  296.727305  260552.15100
# 208         208             3058  ...  296.850164  271863.82550
# 209         209             5133  ...  297.010844  269874.85160
#
# [210 rows x 22 columns]

# %%
input = []

for i in range(len(df)):
  val = []
  val.append(df['ShipDensity_SD'][i])
  val.append(df['UV_SD'][i])
  val.append(df['Vx_SD'][i])
  val.append(df['Vy_SD'][i])
  val.append(df['CloudFraction_SD'][i])
  val.append(df['NO2_SD'][i])
  input.append(val)



inputTest = []

for i in range(len(df)):
  val = []
  val.append(df['ShipDensity_LA'][i])
  val.append(df['UV_LA'][i])
  val.append(df['Vx_LA'][i])
  val.append(df['Vy_LA'][i])
  val.append(df['CloudFraction_LA'][i])
  val.append(df['NO2_LA'][i])
  inputTest.append(val)


input = np.array(input)
inputTest = np.array(inputTest)

# %%
scaler = StandardScaler()
scaler.fit(input)
scaledtrain = scaler.transform(input)

# %%
inputs = keras.Input(shape = (5,))
x = layers.Dense(18, activation='tanh')(inputs)
outputs = layers.Dense(1)(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 5)]               0
# _________________________________________________________________
# dense (Dense)                (None, 18)                108
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 19
# =================================================================
# Total params: 127
# Trainable params: 127
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
historynn = model.fit(scaledtrain[:,:5], scaledtrain[:,5:], epochs = 100, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 42ms/step - loss: 1.2871 - mae: 0.8646 - val_loss: 2.1428 - val_mae: 1.2966
# Epoch 2/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.2292 - mae: 0.8418 - val_loss: 2.0362 - val_mae: 1.2563
# Epoch 3/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.1617 - mae: 0.8142 - val_loss: 1.9442 - val_mae: 1.2206
# Epoch 4/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.1090 - mae: 0.7924 - val_loss: 1.8596 - val_mae: 1.1878
# Epoch 5/100
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0668 - mae: 0.7765 - val_loss: 1.7804 - val_mae: 1.1572
# Epoch 6/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.0291 - mae: 0.7623 - val_loss: 1.6965 - val_mae: 1.1238
# Epoch 7/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.9943 - mae: 0.7514 - val_loss: 1.6294 - val_mae: 1.0961
# Epoch 8/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9664 - mae: 0.7414 - val_loss: 1.5775 - val_mae: 1.0736
# Epoch 9/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9447 - mae: 0.7357 - val_loss: 1.5196 - val_mae: 1.0503
# Epoch 10/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.9233 - mae: 0.7280 - val_loss: 1.4715 - val_mae: 1.0319
# Epoch 11/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9074 - mae: 0.7225 - val_loss: 1.4256 - val_mae: 1.0129
# Epoch 12/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8934 - mae: 0.7173 - val_loss: 1.3889 - val_mae: 0.9982
# Epoch 13/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8808 - mae: 0.7127 - val_loss: 1.3478 - val_mae: 0.9807
# Epoch 14/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8703 - mae: 0.7072 - val_loss: 1.3109 - val_mae: 0.9677
# Epoch 15/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.8620 - mae: 0.7027 - val_loss: 1.2773 - val_mae: 0.9561
# Epoch 16/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8539 - mae: 0.6985 - val_loss: 1.2525 - val_mae: 0.9477
# Epoch 17/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8482 - mae: 0.6951 - val_loss: 1.2222 - val_mae: 0.9369
# Epoch 18/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8434 - mae: 0.6919 - val_loss: 1.2048 - val_mae: 0.9310
# Epoch 19/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8386 - mae: 0.6889 - val_loss: 1.1737 - val_mae: 0.9193
# Epoch 20/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8348 - mae: 0.6867 - val_loss: 1.1583 - val_mae: 0.9137
# Epoch 21/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8312 - mae: 0.6840 - val_loss: 1.1423 - val_mae: 0.9078
# Epoch 22/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8281 - mae: 0.6817 - val_loss: 1.1307 - val_mae: 0.9035
# Epoch 23/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8259 - mae: 0.6803 - val_loss: 1.1125 - val_mae: 0.8963
# Epoch 24/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.8239 - mae: 0.6790 - val_loss: 1.0901 - val_mae: 0.8868
# Epoch 25/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8220 - mae: 0.6772 - val_loss: 1.0799 - val_mae: 0.8828
# Epoch 26/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8202 - mae: 0.6757 - val_loss: 1.0703 - val_mae: 0.8791
# Epoch 27/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8194 - mae: 0.6749 - val_loss: 1.0637 - val_mae: 0.8767
# Epoch 28/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8177 - mae: 0.6738 - val_loss: 1.0525 - val_mae: 0.8721
# Epoch 29/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8169 - mae: 0.6734 - val_loss: 1.0429 - val_mae: 0.8682
# Epoch 30/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8157 - mae: 0.6720 - val_loss: 1.0338 - val_mae: 0.8644
# Epoch 31/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8148 - mae: 0.6714 - val_loss: 1.0276 - val_mae: 0.8615
# Epoch 32/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8132 - mae: 0.6710 - val_loss: 1.0208 - val_mae: 0.8585
# Epoch 33/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8125 - mae: 0.6707 - val_loss: 1.0134 - val_mae: 0.8552
# Epoch 34/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8119 - mae: 0.6703 - val_loss: 1.0088 - val_mae: 0.8532
# Epoch 35/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8105 - mae: 0.6696 - val_loss: 1.0072 - val_mae: 0.8526
# Epoch 36/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8098 - mae: 0.6687 - val_loss: 1.0088 - val_mae: 0.8534
# Epoch 37/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8089 - mae: 0.6681 - val_loss: 1.0067 - val_mae: 0.8525
# Epoch 38/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8083 - mae: 0.6680 - val_loss: 0.9993 - val_mae: 0.8492
# Epoch 39/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.8076 - mae: 0.6679 - val_loss: 1.0023 - val_mae: 0.8507
# Epoch 40/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.8063 - mae: 0.6673 - val_loss: 1.0003 - val_mae: 0.8498
# Epoch 41/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8056 - mae: 0.6670 - val_loss: 1.0004 - val_mae: 0.8500
# Epoch 42/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8048 - mae: 0.6668 - val_loss: 0.9996 - val_mae: 0.8496
# Epoch 43/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8048 - mae: 0.6663 - val_loss: 1.0000 - val_mae: 0.8499
# Epoch 44/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8033 - mae: 0.6657 - val_loss: 0.9951 - val_mae: 0.8476
# Epoch 45/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8024 - mae: 0.6654 - val_loss: 0.9911 - val_mae: 0.8456
# Epoch 46/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8028 - mae: 0.6658 - val_loss: 0.9927 - val_mae: 0.8467
# Epoch 47/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8017 - mae: 0.6655 - val_loss: 0.9848 - val_mae: 0.8426
# Epoch 48/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.
# Epoch 84/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7726 - mae: 0.6554 - val_loss: 0.9837 - val_mae: 0.8400
# Epoch 85/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.7720 - mae: 0.6559 - val_loss: 0.9760 - val_mae: 0.8358
# Epoch 86/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.7707 - mae: 0.6553 - val_loss: 0.9755 - val_mae: 0.8353
# Epoch 87/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7699 - mae: 0.6549 - val_loss: 0.9853 - val_mae: 0.8400
# Epoch 88/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.7701 - mae: 0.6549 - val_loss: 0.9840 - val_mae: 0.8389
# Epoch 89/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7686 - mae: 0.6537 - val_loss: 0.9897 - val_mae: 0.8420
# Epoch 90/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7679 - mae: 0.6531 - val_loss: 0.9839 - val_mae: 0.8393
# Epoch 91/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7670 - mae: 0.6527 - val_loss: 0.9903 - val_mae: 0.8426
# Epoch 92/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7662 - mae: 0.6525 - val_loss: 0.9906 - val_mae: 0.8423
# Epoch 93/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.7653 - mae: 0.6526 - val_loss: 0.9910 - val_mae: 0.8425
# Epoch 94/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7653 - mae: 0.6527 - val_loss: 0.9944 - val_mae: 0.8439
# Epoch 95/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.7641 - mae: 0.6523 - val_loss: 0.9893 - val_mae: 0.8414
# Epoch 96/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.7629 - mae: 0.6524 - val_loss: 0.9857 - val_mae: 0.8395
# Epoch 97/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7623 - mae: 0.6524 - val_loss: 0.9790 - val_mae: 0.8361
# Epoch 98/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7619 - mae: 0.6522 - val_loss: 0.9813 - val_mae: 0.8373
# Epoch 99/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.7610 - mae: 0.6514 - val_loss: 0.9774 - val_mae: 0.8354
# Epoch 100/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.7601 - mae: 0.6512 - val_loss: 0.9769 - val_mae: 0.8346

# %%
lossnn = historynn.history['loss']
val_lossnn = historynn.history['val_loss']
epochs = range(1, len(lossnn) + 1)
plt.plot(epochs, lossnn, 'y', label='training loss')
plt.plot(epochs, val_lossnn, 'r', label='validation loss')
plt.title('Training loss and val loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.legend()
plt.show()

# %%
scaler2 = StandardScaler()
scaler2.fit(inputTest)
scaledtest = scaler2.transform(inputTest)

# %%
inp = []
prediction = []
for i in range(len(inputTest)):
  if(inputTest[i,4])<=0.5:
    forecast = model.predict(scaledtest[i:i+1,:5])
    forecast = np.repeat(forecast, 6, axis = -1)
    predict = scaler2.inverse_transform(forecast)
    inp.append(inputTest[i,5])
    prediction.append(predict[:,5])

plt.plot(inp,  'b', label='actual')
plt.plot(prediction, 'r', label='predicted')
plt.title('Actual vs Predicted NO2 for CF<0.4')
plt.legend()
plt.show()

inp = []
prediction = []
for i in range(len(inputTest)):
  if(inputTest[i,4])>0.5:
    forecast = model.predict(scaledtest[i:i+1,:5])
    forecast = np.repeat(forecast, 6, axis = -1)
    predict = scaler2.inverse_transform(forecast)
    inp.append(inputTest[i,5])
    prediction.append(predict[:,5])

plt.plot(inp,  'b', label='actual')
plt.plot(prediction, 'r', label='predicted')
plt.title('Actual vs Predicted NO2 for CF>0.4')
plt.legend()
plt.show()

# %%
forecast = model.predict(scaledtest[:,:5])
forecast = np.repeat(forecast, 6, axis = -1)
predict = scaler2.inverse_transform(forecast)

plt.plot(inputTest[:, 5],  'b', label='actual')
plt.plot(predict[:, 5], 'r', label='predicted')
plt.title('Actual vs Predicted NO2')
plt.xlabel('Timeseries')
plt.ylabel('NO2 concentration')
plt.legend()
plt.show()
