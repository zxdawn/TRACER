# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/data.csv")

# %%
df
# Out:
#      Unnamed: 0  ShipDensity_GoM  ...     Temp_LA         UV_LA
# 0             0             2714  ...  288.734746  104686.78520
# 1             1               21  ...  289.782862  104370.73440
# 2             2             3290  ...  289.442891   98398.08594
# 3             3             1280  ...  290.500682   95001.85677
# 4             4             1689  ...  290.280014  105785.10290
# ..          ...              ...  ...         ...           ...
# 208         208             3651  ...  296.987956  278598.07550
# 209         209             3103  ...  297.034933  250787.73960
# 210         210             2247  ...  296.727305  260552.15100
# 211         211             3058  ...  296.850164  271863.82550
# 212         212             5133  ...  297.010844  269874.85160
#
# [213 rows x 22 columns]

# %%
sns.pairplot(df, 
              x_vars=["ShipDensity_SD", "UV_SD", "Vx_SD"],
              y_vars=[ "Temp_SD", "CloudFraction_SD", "Vy_SD"],
              hue='NO2_SD', size = 3)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
